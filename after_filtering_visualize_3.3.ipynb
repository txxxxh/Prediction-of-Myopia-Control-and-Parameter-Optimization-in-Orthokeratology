# %% [markdown]
# ## Visualize after filtering

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from scipy.interpolate import interp1d
from scipy.ndimage import gaussian_filter

# --------------------------------------------------------------
# 基本数据加载与预处理函数（matrix_list2中的数据已处理好）
# --------------------------------------------------------------
def load_data(file_path):
    """
    按行加载文本文件数据，每行以空格分隔为浮点数列表
    """
    data = []
    with open(file_path, 'r') as f:
        for line in f:
            if line.strip():
                float_values = [float(value) for value in line.split()]
                data.append(float_values)
    return data

def pad_data(data_list):
    """
    使用零填充构造统一大小的 numpy 数组
    """
    num_rows = len(data_list)
    max_length = max(len(row) for row in data_list)
    pad = np.zeros((num_rows, max_length), dtype=np.float32)
    for i, row in enumerate(data_list):
        pad[i, :len(row)] = np.array(row, dtype=np.float32)
    return pad

def convert_data(data):
    """
    对数据中大于0.1的值进行转换（data = 337.5 / data），0值保持不变
    """
    rows, cols = data.shape
    new_data = data.copy()
    for i in range(rows):
        for j in range(cols):
            if new_data[i, j] > 0.1:
                new_data[i, j] = 337.5 / new_data[i, j]
    return new_data

def Find_vacancy_insert(data, l, upscale_factor=4):
    """
    插值填充缺失数据（值为0的位置）
    """
    data_tail = data[:, -l:]
    data_head = data[:, 0:l]
    data_ext = np.concatenate((data_tail, data, data_head), axis=1)
    n_rows = data_ext.shape[0]
    for i in range(n_rows):
        tmp1 = -1
        vacant_number = 0
        for j in range(len(data_ext[i])):
            if data_ext[i, j] == 0 and vacant_number == 0:
                tmp1 = j
                vacant_number += 1
            elif data_ext[i, j] == 0:
                vacant_number += 1
            elif data_ext[i, j] != 0 and (1 <= vacant_number <= l):
                data_ext[i, tmp1:j] = np.nan
                vacant_number = 0
            elif data_ext[i, j] != 0 and vacant_number > l:
                vacant_number = 0
        if 1 <= vacant_number <= l:
            data_ext[i, tmp1:] = np.nan
    for i in range(n_rows):
        row = data_ext[i]
        nan_idx = np.where(np.isnan(row))[0]
        valid_idx = np.where(~np.isnan(row))[0]
        if valid_idx.size > 0 and nan_idx.size > 0:
            f = interp1d(valid_idx, row[valid_idx], kind='linear', fill_value="extrapolate")
            data_ext[i, nan_idx] = f(nan_idx)
    x_dense = np.linspace(0, data_ext.shape[1] - 1, data_ext.shape[1] * upscale_factor)
    data_dense = np.zeros((data_ext.shape[0], len(x_dense)))
    for i in range(data_ext.shape[0]):
        f = interp1d(np.arange(data_ext.shape[1]), data_ext[i], kind='linear')
        data_dense[i] = f(x_dense)
    return data_dense[:, l * upscale_factor: -l * upscale_factor]

# --------------------------------------------------------------
# 工具函数：将2D数据转换为同心圆坐标
# --------------------------------------------------------------
def get_circle_coords(data, max_radius=5):
    """
    将二维矩阵 data 转换为同心圆坐标，返回 x_all, y_all, c_all（c_all 为数据展开后的值）
    参数：
      data: 每行代表一个圆环的采样值；
      max_radius: 图中最大半径，用于确定采样步长
    """
    data_t = data.T
    n_rings = data_t.shape[0]
    radius_step = max_radius / n_rings
    x_list, y_list = [], []
    for i in range(n_rings):
        theta = np.linspace(0, 2 * np.pi, data_t.shape[1], endpoint=False)
        r = i * radius_step
        x_list.append(r * np.cos(theta))
        y_list.append(r * np.sin(theta))
    x_all = np.concatenate(x_list)
    y_all = np.concatenate(y_list)
    c_all = np.concatenate(list(data_t))
    return x_all, y_all, c_all

# --------------------------------------------------------------
# 自定义颜色映射函数
# --------------------------------------------------------------
def _get_custom_cmap():
    """
    构造自定义颜色映射，数据值范围35到50，颜色节点如下：
      35：#000064  
      36：#00007f  
      37：#0000d1  
      38：#002dff  
      39：#0077ff  
      40：#00c6ff  
      41：#00ffd8  
      42：#00ff70  
      43：#00ff00  
      44：#70ff00  
      45：#d8ff00  
      46：#ffce00  
      47：#ff8e00  
      48：#ff4f00  
      49：#ff0f00  
      50：#bf0000
    """
    color_list = [
        (0.0, "#000064"),               # 35 -> normalized 0.0
        (1/15, "#00007f"),              # 36 -> (36-35)/15 ≈ 0.0667
        (2/15, "#0000d1"),              # 37 -> (37-35)/15 ≈ 0.1333
        (3/15, "#002dff"),              # 38 -> (38-35)/15 = 0.2
        (4/15, "#0077ff"),              # 39 -> (39-35)/15 ≈ 0.2667
        (5/15, "#00c6ff"),              # 40 -> (40-35)/15 ≈ 0.3333
        (6/15, "#00ffd8"),              # 41 -> (41-35)/15 = 0.4
        (7/15, "#00ff70"),              # 42 -> (42-35)/15 ≈ 0.4667
        (8/15, "#00ff00"),              # 43 -> (43-35)/15 ≈ 0.5333
        (9/15, "#70ff00"),              # 44 -> (44-35)/15 = 0.6
        (10/15, "#d8ff00"),             # 45 -> (45-35)/15 ≈ 0.6667
        (11/15, "#ffce00"),             # 46 -> (46-35)/15 ≈ 0.7333
        (12/15, "#ff8e00"),             # 47 -> (47-35)/15 = 0.8
        (13/15, "#ff4f00"),             # 48 -> (48-35)/15 ≈ 0.8667
        (14/15, "#ff0f00"),             # 49 -> (49-35)/15 ≈ 0.9333
        (1.0, "#bf0000")                # 50 -> normalized 1.0
    ]
    cmap = LinearSegmentedColormap.from_list("custom_heat", color_list, N=256)
    return cmap

# --------------------------------------------------------------
# 可视化函数——将数据以同心圆格式显示
# --------------------------------------------------------------
def visualize_circle(data, title="", max_radius=5, save_path=None):
    """
    将二维矩阵 data 转换为同心圆图并显示，并可选择保存图像
    """
    x_all, y_all, c_all = get_circle_coords(data, max_radius=max_radius)
    cmap = _get_custom_cmap()  # 使用自定义颜色映射
    
    plt.figure(figsize=(10, 8))
    sc = plt.scatter(x_all, y_all, c=c_all, cmap=cmap)
    sc.set_clim(30, 50)  # 设置colorbar范围

    plt.title(title, fontsize=14)
    plt.axis('off')
    plt.xlim(-max_radius, max_radius)
    plt.ylim(-max_radius, max_radius)

    cbar = plt.colorbar(sc)  # colorbar 会遵循设定的 clim
    
    # 保存图像
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')

    plt.show()




import os
import glob

# 原始数据路径
root_dir = "/Users/txh/Desktop/research/lwk/ok/6.0_after_filtering"
# 目标存储路径
output_root = "/Users/txh/Desktop/research/lwk/ok/6.0_original"

# 遍历所有 .tgl 文件
file_paths = sorted(glob.glob(os.path.join(root_dir, "**", "*.tgl"), recursive=True))

for file_path in file_paths:
    # 加载数据
    data = load_data(file_path)
    padded_data = pad_data(data)
    inserted_data = Find_vacancy_insert(padded_data, 15, upscale_factor=10)  # 增加插值密集度
    
    # 计算对应的相对路径
    relative_path = os.path.relpath(file_path, root_dir)  # 获取相对路径
    new_dir = os.path.join(output_root, os.path.dirname(relative_path))  # 生成新目录路径
    os.makedirs(new_dir, exist_ok=True)  # 递归创建目录（如果不存在）

    # 生成新文件路径
    new_file_name = os.path.basename(file_path).replace(".tgl", "_original.png")  # 修改文件名
    save_path = os.path.join(new_dir, new_file_name)  # 拼接最终存储路径

    # 处理并保存
    visualize_circle(inserted_data, title="test", max_radius=5, save_path=save_path)

    print(f"处理完成: {file_path} -> {save_path}")

# %% [markdown]
# ## Segmentation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import os
import glob

def kmeans_segmentation(image_path, k=3, save_path=None):
    """
    利用 K-means 聚类对图像像素进行分割。
    """
    # 读取图像
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"无法加载图像: {image_path}")
    
    # 转换为 RGB 方便后续处理
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    pixel_vals = image_rgb.reshape((-1, 3))
    pixel_vals = np.float32(pixel_vals)

    # K-means 聚类
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=100, random_state=42)
    labels = kmeans.fit_predict(pixel_vals)
    centers = kmeans.cluster_centers_.astype(np.uint8)

    # 生成分割后的图像
    segmented_data = centers[labels]
    seg_img_rgb = segmented_data.reshape(image_rgb.shape)

    # 转换回 BGR 格式
    seg_img = cv2.cvtColor(seg_img_rgb, cv2.COLOR_RGB2BGR)
    labels_2d = labels.reshape((image.shape[0], image.shape[1]))

    # **保存图像**
    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        cv2.imwrite(save_path, seg_img)

    return labels_2d, centers, seg_img

# **路径定义**
input_root = "/Users/txh/Desktop/research/lwk/ok/6.0_original"  # 原始图像目录
output_root = "/Users/txh/Desktop/kmeans_segment"  # 结果保存目录

# 遍历所有 .png 文件
file_paths = sorted(glob.glob(os.path.join(input_root, "**", "*.png"), recursive=True))

for file_path in file_paths:
    # 计算对应的相对路径
    relative_path = os.path.relpath(file_path, input_root)
    new_dir = os.path.join(output_root, os.path.dirname(relative_path))  # 生成新目录路径
    os.makedirs(new_dir, exist_ok=True)  # 递归创建目录

    # 生成新文件路径
    new_file_name = os.path.basename(file_path).replace(".png", "_kmeans_segment.png")  # 修改文件名
    save_path = os.path.join(new_dir, new_file_name)

    # 处理并保存
    kmeans_segmentation(file_path, k=4, save_path=save_path)

    print(f"处理完成: {file_path} -> {save_path}")
# Out:
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/1/period1_0001yukaize_Left_2020-8-15_15-03-51_original.png -> /Users/txh/Desktop/kmeans_segment/1/period1_0001yukaize_Left_2020-8-15_15-03-51_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/1/period2_0001yukaize_Left_2022-01-8_14-05-36_original.png -> /Users/txh/Desktop/kmeans_segment/1/period2_0001yukaize_Left_2022-01-8_14-05-36_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/1/period3_0001yukaize_Left_2022-02-19_14-05-29_original.png -> /Users/txh/Desktop/kmeans_segment/1/period3_0001yukaize_Left_2022-02-19_14-05-29_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/1/period4_0001yukaize_Left_2022-06-24_13-58-25_original.png -> /Users/txh/Desktop/kmeans_segment/1/period4_0001yukaize_Left_2022-06-24_13-58-25_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/1/period5_0001yukaize_Left_2022-10-22_14-29-43_original.png -> /Users/txh/Desktop/kmeans_segment/1/period5_0001yukaize_Left_2022-10-22_14-29-43_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/10/period1_0011chenyining_Left_2021-04-30_14-02-06_original.png -> /Users/txh/Desktop/kmeans_segment/10/period1_0011chenyining_Left_2021-04-30_14-02-06_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/10/period2_0011chenyining_Left_2021-06-6_11-26-28_original.png -> /Users/txh/Desktop/kmeans_segment/10/period2_0011chenyining_Left_2021-06-6_11-26-28_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/10/period3_0011chenyining_Left_2021-08-8_11-36-06_original.png -> /Users/txh/Desktop/kmeans_segment/10/period3_0011chenyining_Left_2021-08-8_11-36-06_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/10/period4_0011chenyining_Left_2021-11-5_16-38-37_original.png -> /Users/txh/Desktop/kmeans_segment/10/period4_0011chenyining_Left_2021-11-5_16-38-37_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/10/period5_0011chenyining_Left_2022-03-11_16-22-52_original.png -> /Users/txh/Desktop/kmeans_segment/10/period5_0011chenyining_Left_2022-03-11_16-22-52_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/11/period1_0012wubohan_Left_2019-09-28_15-15-19_original.png -> /Users/txh/Desktop/kmeans_segment/11/period1_0012wubohan_Left_2019-09-28_15-15-19_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/11/period2_0012wubohan_Left_2019-11-9_09-31-20_original.png -> /Users/txh/Desktop/kmeans_segment/11/period2_0012wubohan_Left_2019-11-9_09-31-20_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/11/period3_0012wubohan_Left_2019-12-7_09-32-06_original.png -> /Users/txh/Desktop/kmeans_segment/11/period3_0012wubohan_Left_2019-12-7_09-32-06_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/11/period4_0012wubohan_Left_2020-04-3_14-06-03_original.png -> /Users/txh/Desktop/kmeans_segment/11/period4_0012wubohan_Left_2020-04-3_14-06-03_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/11/period5_0012wubohan_Left_2020-10-18_14-38-51_original.png -> /Users/txh/Desktop/kmeans_segment/11/period5_0012wubohan_Left_2020-10-18_14-38-51_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/12/period1_0013yaoyushan_Left_2019-07-28_19-12-13_original.png -> /Users/txh/Desktop/kmeans_segment/12/period1_0013yaoyushan_Left_2019-07-28_19-12-13_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/12/period2_0013yaoyushan_Left_2019-08-30_13-22-54_original.png -> /Users/txh/Desktop/kmeans_segment/12/period2_0013yaoyushan_Left_2019-08-30_13-22-54_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/12/period3_0013yaoyushan_Left_2019-11-23_13-38-58_original.png -> /Users/txh/Desktop/kmeans_segment/12/period3_0013yaoyushan_Left_2019-11-23_13-38-58_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/12/period4_0013yaoyushan_Left_2019-12-28_14-16-29_original.png -> /Users/txh/Desktop/kmeans_segment/12/period4_0013yaoyushan_Left_2019-12-28_14-16-29_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/12/period5_0013yaoyushan_Left_2020-05-2_13-11-39_original.png -> /Users/txh/Desktop/kmeans_segment/12/period5_0013yaoyushan_Left_2020-05-2_13-11-39_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/13/period1_0014yaohuanyu_Left_2021-02-28_15-48-08_original.png -> /Users/txh/Desktop/kmeans_segment/13/period1_0014yaohuanyu_Left_2021-02-28_15-48-08_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/13/period2_0014yaohuanyu_Left_2021-04-17_09-09-10_original.png -> /Users/txh/Desktop/kmeans_segment/13/period2_0014yaohuanyu_Left_2021-04-17_09-09-10_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/13/period3_0014yaohuanyu_Left_2021-07-10_10-14-46_original.png -> /Users/txh/Desktop/kmeans_segment/13/period3_0014yaohuanyu_Left_2021-07-10_10-14-46_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/13/period4_0014yaohuanyu_Left_2021-10-30_17-20-28_original.png -> /Users/txh/Desktop/kmeans_segment/13/period4_0014yaohuanyu_Left_2021-10-30_17-20-28_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/13/period5_0014yaohuanyu_Left_2022-05-28_10-59-05_original.png -> /Users/txh/Desktop/kmeans_segment/13/period5_0014yaohuanyu_Left_2022-05-28_10-59-05_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/14/period1_0015jiyuheng_Left_2021-12-5_11-30-39_original.png -> /Users/txh/Desktop/kmeans_segment/14/period1_0015jiyuheng_Left_2021-12-5_11-30-39_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/14/period2_0015jiyuheng_Left_2022-01-23_11-41-22_original.png -> /Users/txh/Desktop/kmeans_segment/14/period2_0015jiyuheng_Left_2022-01-23_11-41-22_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/14/period3_0015jiyuheng_Left_2022-02-27_12-01-26_original.png -> /Users/txh/Desktop/kmeans_segment/14/period3_0015jiyuheng_Left_2022-02-27_12-01-26_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/14/period4_0015jiyuheng_Left_2022-06-25_15-44-15_original.png -> /Users/txh/Desktop/kmeans_segment/14/period4_0015jiyuheng_Left_2022-06-25_15-44-15_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/14/period5_0015jiyuheng_Left_2022-10-29_11-22-52_original.png -> /Users/txh/Desktop/kmeans_segment/14/period5_0015jiyuheng_Left_2022-10-29_11-22-52_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/15/period1_0016sunjiawei_Left_2021-11-14_09-26-59_original.png -> /Users/txh/Desktop/kmeans_segment/15/period1_0016sunjiawei_Left_2021-11-14_09-26-59_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/15/period2_0016sunjiawei_Left_2021-12-12_09-40-47_original.png -> /Users/txh/Desktop/kmeans_segment/15/period2_0016sunjiawei_Left_2021-12-12_09-40-47_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/15/period3_0016sunjiawei_Left_2022-02-19_11-36-50_original.png -> /Users/txh/Desktop/kmeans_segment/15/period3_0016sunjiawei_Left_2022-02-19_11-36-50_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/15/period4_0016sunjiawei_Left_2022-06-26_15-28-32_original.png -> /Users/txh/Desktop/kmeans_segment/15/period4_0016sunjiawei_Left_2022-06-26_15-28-32_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/15/period5_0016sunjiawei_Left_2023-02-11_15-44-03_original.png -> /Users/txh/Desktop/kmeans_segment/15/period5_0016sunjiawei_Left_2023-02-11_15-44-03_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/16/period1_0018songyuchen_Left_2019-11-16_14-11-33_original.png -> /Users/txh/Desktop/kmeans_segment/16/period1_0018songyuchen_Left_2019-11-16_14-11-33_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/16/period2_0018songyuchen_Left_2019-12-21_10-35-06_original.png -> /Users/txh/Desktop/kmeans_segment/16/period2_0018songyuchen_Left_2019-12-21_10-35-06_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/16/period3_0018songyuchen_Left_2020-03-21_08-55-17_original.png -> /Users/txh/Desktop/kmeans_segment/16/period3_0018songyuchen_Left_2020-03-21_08-55-17_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/16/period4_0018songyuchen_Left_2020-06-20_09-27-39_original.png -> /Users/txh/Desktop/kmeans_segment/16/period4_0018songyuchen_Left_2020-06-20_09-27-39_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/16/period5_0018songyuchen_Left_2020-11-20_16-51-14_original.png -> /Users/txh/Desktop/kmeans_segment/16/period5_0018songyuchen_Left_2020-11-20_16-51-14_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/17/period1_0019yinyuexi_Left_2020-09-26_16-04-40_original.png -> /Users/txh/Desktop/kmeans_segment/17/period1_0019yinyuexi_Left_2020-09-26_16-04-40_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/17/period2_0019yinyuexi_Left_2020-11-22_09-47-00_original.png -> /Users/txh/Desktop/kmeans_segment/17/period2_0019yinyuexi_Left_2020-11-22_09-47-00_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/17/period4_0019yinyuexi_Left_2021-04-11_09-53-59_original.png -> /Users/txh/Desktop/kmeans_segment/17/period4_0019yinyuexi_Left_2021-04-11_09-53-59_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/17/period5_0019yinyuexi_Left_2021-11-28_11-22-41_original.png -> /Users/txh/Desktop/kmeans_segment/17/period5_0019yinyuexi_Left_2021-11-28_11-22-41_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/18/period1_0020zhangyongshan_Left_2021-07-10_14-05-19_original.png -> /Users/txh/Desktop/kmeans_segment/18/period1_0020zhangyongshan_Left_2021-07-10_14-05-19_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/18/period2_0020zhangyongshan_Left_2021-08-14_15-19-05_original.png -> /Users/txh/Desktop/kmeans_segment/18/period2_0020zhangyongshan_Left_2021-08-14_15-19-05_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/18/period3_0020zhangyongshan_Left_2021-10-10_14-19-21_original.png -> /Users/txh/Desktop/kmeans_segment/18/period3_0020zhangyongshan_Left_2021-10-10_14-19-21_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/18/period4_0020zhangyongshan_Left_2022-2-26_10-43-50_original.png -> /Users/txh/Desktop/kmeans_segment/18/period4_0020zhangyongshan_Left_2022-2-26_10-43-50_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/18/period5_0020zhangyongshan_Left_2022-09-24_10-11-43_original.png -> /Users/txh/Desktop/kmeans_segment/18/period5_0020zhangyongshan_Left_2022-09-24_10-11-43_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/19/period1_0021zhangxiaohe_Left_2020-10-7_18-01-54_original.png -> /Users/txh/Desktop/kmeans_segment/19/period1_0021zhangxiaohe_Left_2020-10-7_18-01-54_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/19/period3_0021zhangxiaohe_Left_2021-3-27_15-47-06_original.png -> /Users/txh/Desktop/kmeans_segment/19/period3_0021zhangxiaohe_Left_2021-3-27_15-47-06_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/19/period4_0021zhangxiaohe_Left_2021-05-15_17-18-00_original.png -> /Users/txh/Desktop/kmeans_segment/19/period4_0021zhangxiaohe_Left_2021-05-15_17-18-00_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/19/period5_0021zhangxiaohe_Left_2021-11-13_10-24-40_original.png -> /Users/txh/Desktop/kmeans_segment/19/period5_0021zhangxiaohe_Left_2021-11-13_10-24-40_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/2/period1_0002yijilin_Left_2018-11-16_16-39-32_original.png -> /Users/txh/Desktop/kmeans_segment/2/period1_0002yijilin_Left_2018-11-16_16-39-32_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/2/period2_0002yijilin_Left_2019-01-4_13-52-25_original.png -> /Users/txh/Desktop/kmeans_segment/2/period2_0002yijilin_Left_2019-01-4_13-52-25_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/2/period3_0002yijilin_Left_2019-02-23_13-14-30_original.png -> /Users/txh/Desktop/kmeans_segment/2/period3_0002yijilin_Left_2019-02-23_13-14-30_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/2/period4_0002yijilin_Left_2019-06-14_15-43-33_original.png -> /Users/txh/Desktop/kmeans_segment/2/period4_0002yijilin_Left_2019-06-14_15-43-33_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/2/period5_0002yijilin_Left_2020-01-3_16-07-14_original.png -> /Users/txh/Desktop/kmeans_segment/2/period5_0002yijilin_Left_2020-01-3_16-07-14_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/20/period1_0022zhangjiahui_Left_2020-08-29_11-26-24_original.png -> /Users/txh/Desktop/kmeans_segment/20/period1_0022zhangjiahui_Left_2020-08-29_11-26-24_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/20/period2_0022zhangjiahui_Left_2020-11-15_14-49-31_original.png -> /Users/txh/Desktop/kmeans_segment/20/period2_0022zhangjiahui_Left_2020-11-15_14-49-31_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/20/period3_0022zhangjiahui_Left_2020-12-20_09-35-49_original.png -> /Users/txh/Desktop/kmeans_segment/20/period3_0022zhangjiahui_Left_2020-12-20_09-35-49_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/20/period4_0022zhangjiahui_Left_2021-7-2_14-18-31_original.png -> /Users/txh/Desktop/kmeans_segment/20/period4_0022zhangjiahui_Left_2021-7-2_14-18-31_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/20/period5_0022zhangjiahui_Left_2022-01-23_15-58-43_original.png -> /Users/txh/Desktop/kmeans_segment/20/period5_0022zhangjiahui_Left_2022-01-23_15-58-43_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/21/period1_0023xuyezi_Left_2019-07-6_14-27-23_original.png -> /Users/txh/Desktop/kmeans_segment/21/period1_0023xuyezi_Left_2019-07-6_14-27-23_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/21/period2_0023xuyezi_Left_2019-08-9_15-39-42_original.png -> /Users/txh/Desktop/kmeans_segment/21/period2_0023xuyezi_Left_2019-08-9_15-39-42_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/21/period3_0023xuyezi_Left_2019-10-26_11-48-31_original.png -> /Users/txh/Desktop/kmeans_segment/21/period3_0023xuyezi_Left_2019-10-26_11-48-31_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/21/period4_0023xuyezi_Left_2019-11-22_16-25-00_original.png -> /Users/txh/Desktop/kmeans_segment/21/period4_0023xuyezi_Left_2019-11-22_16-25-00_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/21/period5_0023xuyezi_Left_2020-07-25_09-04-39_original.png -> /Users/txh/Desktop/kmeans_segment/21/period5_0023xuyezi_Left_2020-07-25_09-04-39_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/22/period1_0024zhanminxi_Left_2019-11-23_15-20-55_original.png -> /Users/txh/Desktop/kmeans_segment/22/period1_0024zhanminxi_Left_2019-11-23_15-20-55_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/22/period2_0024zhanminxi_Left_2019-12-28_15-44-26_original.png -> /Users/txh/Desktop/kmeans_segment/22/period2_0024zhanminxi_Left_2019-12-28_15-44-26_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/22/period3_0024zhanminxi_Left_2020-1-11_16-15-19_original.png -> /Users/txh/Desktop/kmeans_segment/22/period3_0024zhanminxi_Left_2020-1-11_16-15-19_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/22/period4_0024zhanminxi_Left_2020-08-15_11-52-13_original.png -> /Users/txh/Desktop/kmeans_segment/22/period4_0024zhanminxi_Left_2020-08-15_11-52-13_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/22/period5_0024zhanminxi_Left_2020-10-11_14-42-46_original.png -> /Users/txh/Desktop/kmeans_segment/22/period5_0024zhanminxi_Left_2020-10-11_14-42-46_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/23/period1_0025zhujiayi_Left_2020-11-29_10-45-34_original.png -> /Users/txh/Desktop/kmeans_segment/23/period1_0025zhujiayi_Left_2020-11-29_10-45-34_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/23/period2_0025zhujiayi_Left_2021-01-17_10-10-39_original.png -> /Users/txh/Desktop/kmeans_segment/23/period2_0025zhujiayi_Left_2021-01-17_10-10-39_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/23/period3_0025zhujiayi_Left_2021-04-11_10-08-30_original.png -> /Users/txh/Desktop/kmeans_segment/23/period3_0025zhujiayi_Left_2021-04-11_10-08-30_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/23/period4_0025zhujiayi_Left_2021-9-11_10-55-34_original.png -> /Users/txh/Desktop/kmeans_segment/23/period4_0025zhujiayi_Left_2021-9-11_10-55-34_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/23/period5_0025zhujiayi_Left_2021-11-28_10-41-59_original.png -> /Users/txh/Desktop/kmeans_segment/23/period5_0025zhujiayi_Left_2021-11-28_10-41-59_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/24/period1_0027liyuqing_Left_2020-07-12_16-24-06_original.png -> /Users/txh/Desktop/kmeans_segment/24/period1_0027liyuqing_Left_2020-07-12_16-24-06_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/24/period3_0027liyuqing_Left_2020-09-12_12-11-47_original.png -> /Users/txh/Desktop/kmeans_segment/24/period3_0027liyuqing_Left_2020-09-12_12-11-47_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/24/period4_0027liyuqing_Left_2020-12-13_11-52-41_original.png -> /Users/txh/Desktop/kmeans_segment/24/period4_0027liyuqing_Left_2020-12-13_11-52-41_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/24/period5_0027liyuqing_Left_2021-07-17_11-40-04_original.png -> /Users/txh/Desktop/kmeans_segment/24/period5_0027liyuqing_Left_2021-07-17_11-40-04_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/25/period1_0028duyixin_Left_2021-06-13_16-34-51_original.png -> /Users/txh/Desktop/kmeans_segment/25/period1_0028duyixin_Left_2021-06-13_16-34-51_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/25/period2_0028duyixin_Left_2021-07-25_08-59-31_original.png -> /Users/txh/Desktop/kmeans_segment/25/period2_0028duyixin_Left_2021-07-25_08-59-31_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/25/period3_0028duyixin_Left_2021-10-23_09-41-12_original.png -> /Users/txh/Desktop/kmeans_segment/25/period3_0028duyixin_Left_2021-10-23_09-41-12_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/25/period4_0028duyixin_Left_2022-01-9_10-24-38_original.png -> /Users/txh/Desktop/kmeans_segment/25/period4_0028duyixin_Left_2022-01-9_10-24-38_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/25/period5_0028duyixin_Left_2022-10-21_13-58-02_original.png -> /Users/txh/Desktop/kmeans_segment/25/period5_0028duyixin_Left_2022-10-21_13-58-02_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/26/period1_0030pujingwen_Left_2020-07-11_09-54-51_original.png -> /Users/txh/Desktop/kmeans_segment/26/period1_0030pujingwen_Left_2020-07-11_09-54-51_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/26/period2_0030pujingwen_Left_2020-08-16_09-22-11_original.png -> /Users/txh/Desktop/kmeans_segment/26/period2_0030pujingwen_Left_2020-08-16_09-22-11_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/26/period3_0030pujingwen_Left_2020-09-26_09-27-30_original.png -> /Users/txh/Desktop/kmeans_segment/26/period3_0030pujingwen_Left_2020-09-26_09-27-30_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/26/period4_0030pujingwen_Left_2020-11-28_09-48-27_original.png -> /Users/txh/Desktop/kmeans_segment/26/period4_0030pujingwen_Left_2020-11-28_09-48-27_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/26/period5_0030pujingwen_Left_2021-07-3_09-20-32_original.png -> /Users/txh/Desktop/kmeans_segment/26/period5_0030pujingwen_Left_2021-07-3_09-20-32_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/27/period1_0031wangjiayi_Left_2020-08-16_13-19-32_original.png -> /Users/txh/Desktop/kmeans_segment/27/period1_0031wangjiayi_Left_2020-08-16_13-19-32_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/27/period2_0031wangjiayi_Left_2020-10-11_16-13-21_original.png -> /Users/txh/Desktop/kmeans_segment/27/period2_0031wangjiayi_Left_2020-10-11_16-13-21_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/27/period3_0031wangjiayi_Left_2020-12-27_15-06-18_original.png -> /Users/txh/Desktop/kmeans_segment/27/period3_0031wangjiayi_Left_2020-12-27_15-06-18_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/27/period4_0031wangjiayi_Left_2021-05-9_16-26-05_original.png -> /Users/txh/Desktop/kmeans_segment/27/period4_0031wangjiayi_Left_2021-05-9_16-26-05_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/27/period5_0031wangjiayi_Left_2021-11-28_10-31-57_original.png -> /Users/txh/Desktop/kmeans_segment/27/period5_0031wangjiayi_Left_2021-11-28_10-31-57_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/28/period1_0032wangjiale_Left_2021-06-26_10-13-30_original.png -> /Users/txh/Desktop/kmeans_segment/28/period1_0032wangjiale_Left_2021-06-26_10-13-30_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/28/period2_0032wangjiale_Left_2021-08-8_11-14-11_original.png -> /Users/txh/Desktop/kmeans_segment/28/period2_0032wangjiale_Left_2021-08-8_11-14-11_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/28/period3_0032wangjiale_Left_2021-11-6_14-08-44_original.png -> /Users/txh/Desktop/kmeans_segment/28/period3_0032wangjiale_Left_2021-11-6_14-08-44_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/28/period4_0032wangjiale_Left_2022-01-22_11-24-26_original.png -> /Users/txh/Desktop/kmeans_segment/28/period4_0032wangjiale_Left_2022-01-22_11-24-26_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/28/period5_0032wangjiale_Left_2022-3-19_14-05-31_original.png -> /Users/txh/Desktop/kmeans_segment/28/period5_0032wangjiale_Left_2022-3-19_14-05-31_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/29/period1_0036sulang_Left_2018-07-29_13-48-09_original.png -> /Users/txh/Desktop/kmeans_segment/29/period1_0036sulang_Left_2018-07-29_13-48-09_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/29/period2_0036sulang_Left_2018-09-22_16-22-41_original.png -> /Users/txh/Desktop/kmeans_segment/29/period2_0036sulang_Left_2018-09-22_16-22-41_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/29/period3_0036sulang_Left_2018-10-27_12-05-30_original.png -> /Users/txh/Desktop/kmeans_segment/29/period3_0036sulang_Left_2018-10-27_12-05-30_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/29/period4_0036sulang_Left_2019-04-6_11-18-22_original.png -> /Users/txh/Desktop/kmeans_segment/29/period4_0036sulang_Left_2019-04-6_11-18-22_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/29/period5_0036sulang_Left_2019-05-18_09-57-20_original.png -> /Users/txh/Desktop/kmeans_segment/29/period5_0036sulang_Left_2019-05-18_09-57-20_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/3/period1_0003hesihan_Left_2021-04-11_10-20-00_original.png -> /Users/txh/Desktop/kmeans_segment/3/period1_0003hesihan_Left_2021-04-11_10-20-00_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/3/period2_0003hesihan_Left_2021-05-16_10-27-12_original.png -> /Users/txh/Desktop/kmeans_segment/3/period2_0003hesihan_Left_2021-05-16_10-27-12_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/3/period3_0003hesihan_Left_2021-06-26_15-32-02_original.png -> /Users/txh/Desktop/kmeans_segment/3/period3_0003hesihan_Left_2021-06-26_15-32-02_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/3/period4_0003hesihan_Left_2021-10-7_11-09-41_original.png -> /Users/txh/Desktop/kmeans_segment/3/period4_0003hesihan_Left_2021-10-7_11-09-41_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/3/period5_0003hesihan_Left_2022-07-10_09-34-57_original.png -> /Users/txh/Desktop/kmeans_segment/3/period5_0003hesihan_Left_2022-07-10_09-34-57_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/30/period1_0039zhaoyihong_Left_2020-11-22_09-26-46_original.png -> /Users/txh/Desktop/kmeans_segment/30/period1_0039zhaoyihong_Left_2020-11-22_09-26-46_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/30/period2_0039zhaoyihong_Left_2020-12-27_09-45-22_original.png -> /Users/txh/Desktop/kmeans_segment/30/period2_0039zhaoyihong_Left_2020-12-27_09-45-22_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/30/period3_0039zhaoyihong_Left_2021-02-6_10-16-23_original.png -> /Users/txh/Desktop/kmeans_segment/30/period3_0039zhaoyihong_Left_2021-02-6_10-16-23_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/30/period4_0039zhaoyihong_Left_2021-04-18_10-54-49_original.png -> /Users/txh/Desktop/kmeans_segment/30/period4_0039zhaoyihong_Left_2021-04-18_10-54-49_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/30/period5_0039zhaoyihong_Left_2021-10-4_14-35-58_original.png -> /Users/txh/Desktop/kmeans_segment/30/period5_0039zhaoyihong_Left_2021-10-4_14-35-58_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/31/period1_0040xinxinyi_Left_2020-11-21_16-12-39_original.png -> /Users/txh/Desktop/kmeans_segment/31/period1_0040xinxinyi_Left_2020-11-21_16-12-39_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/31/period2_0040xinxinyi_Left_2021-01-10_14-33-41_original.png -> /Users/txh/Desktop/kmeans_segment/31/period2_0040xinxinyi_Left_2021-01-10_14-33-41_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/31/period3_0040xinxinyi_Left_2021-03-21_15-52-31_original.png -> /Users/txh/Desktop/kmeans_segment/31/period3_0040xinxinyi_Left_2021-03-21_15-52-31_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/31/period4_0040xinxinyi_Left_2021-8-22_11-54-50_original.png -> /Users/txh/Desktop/kmeans_segment/31/period4_0040xinxinyi_Left_2021-8-22_11-54-50_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/31/period5_0040xinxinyi_Left_2021-12-11_14-10-21_original.png -> /Users/txh/Desktop/kmeans_segment/31/period5_0040xinxinyi_Left_2021-12-11_14-10-21_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/32/period1_0041haojianmo_Left_2021-12-25_15-14-56_original.png -> /Users/txh/Desktop/kmeans_segment/32/period1_0041haojianmo_Left_2021-12-25_15-14-56_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/32/period2_0041haojianmo_Right_2022-02-11_14-14-30_original.png -> /Users/txh/Desktop/kmeans_segment/32/period2_0041haojianmo_Right_2022-02-11_14-14-30_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/32/period3_0041haojianmo_Left_2022-03-20_11-41-29_original.png -> /Users/txh/Desktop/kmeans_segment/32/period3_0041haojianmo_Left_2022-03-20_11-41-29_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/32/period4_0041haojianmo_Left_2022-06-4_13-37-07_original.png -> /Users/txh/Desktop/kmeans_segment/32/period4_0041haojianmo_Left_2022-06-4_13-37-07_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/32/period5_0041haojianmo_Left_2022-12-24_09-56-01_original.png -> /Users/txh/Desktop/kmeans_segment/32/period5_0041haojianmo_Left_2022-12-24_09-56-01_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/33/period1_0042guoyifei_Left_2020-09-11_15-11-15_original.png -> /Users/txh/Desktop/kmeans_segment/33/period1_0042guoyifei_Left_2020-09-11_15-11-15_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/33/period3_0042guoyifei_Left_2020-12-13_14-29-40_original.png -> /Users/txh/Desktop/kmeans_segment/33/period3_0042guoyifei_Left_2020-12-13_14-29-40_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/33/period4_0042guoyifei_Left_2021-04-11_16-43-52_original.png -> /Users/txh/Desktop/kmeans_segment/33/period4_0042guoyifei_Left_2021-04-11_16-43-52_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/33/period5_0042guoyifei_Left_2021-06-25_16-05-26_original.png -> /Users/txh/Desktop/kmeans_segment/33/period5_0042guoyifei_Left_2021-06-25_16-05-26_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/34/period1_0043huangzhixin_Left_2021-08-6_14-02-40_original.png -> /Users/txh/Desktop/kmeans_segment/34/period1_0043huangzhixin_Left_2021-08-6_14-02-40_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/34/period2_0043huangzhixin_Left_2021-10-24_11-27-45_original.png -> /Users/txh/Desktop/kmeans_segment/34/period2_0043huangzhixin_Left_2021-10-24_11-27-45_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/34/period3_0043huangzhixin_Left_2021-11-28_14-44-13_original.png -> /Users/txh/Desktop/kmeans_segment/34/period3_0043huangzhixin_Left_2021-11-28_14-44-13_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/34/period4_0043huangzhixin_Left_2022-03-5_15-19-53_original.png -> /Users/txh/Desktop/kmeans_segment/34/period4_0043huangzhixin_Left_2022-03-5_15-19-53_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/34/period5_0043huangzhixin_Left_2022-10-22_12-00-56_original.png -> /Users/txh/Desktop/kmeans_segment/34/period5_0043huangzhixin_Left_2022-10-22_12-00-56_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/35/period1_0045liuningxuan_Left_2018-06-30_12-02-11_original.png -> /Users/txh/Desktop/kmeans_segment/35/period1_0045liuningxuan_Left_2018-06-30_12-02-11_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/35/period2_0045liuningxuan_Left_2018-9-8_13-52-36_original.png -> /Users/txh/Desktop/kmeans_segment/35/period2_0045liuningxuan_Left_2018-9-8_13-52-36_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/35/period3_0045liuningxuan_Left_2018-10-13_11-45-10_original.png -> /Users/txh/Desktop/kmeans_segment/35/period3_0045liuningxuan_Left_2018-10-13_11-45-10_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/35/period4_0045liuningxuan_Left_2018-12-15_11-49-28_original.png -> /Users/txh/Desktop/kmeans_segment/35/period4_0045liuningxuan_Left_2018-12-15_11-49-28_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/35/period5_0045liuningxuan_Left_2019-04-13_12-18-39_original.png -> /Users/txh/Desktop/kmeans_segment/35/period5_0045liuningxuan_Left_2019-04-13_12-18-39_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/36/period1_0046yangzhengxuan_Left_2019-12-20_16-28-32_original.png -> /Users/txh/Desktop/kmeans_segment/36/period1_0046yangzhengxuan_Left_2019-12-20_16-28-32_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/36/period3_0046yangzhengxuan_Left_2020-04-10_13-17-05_original.png -> /Users/txh/Desktop/kmeans_segment/36/period3_0046yangzhengxuan_Left_2020-04-10_13-17-05_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/36/period4_0046yangzhengxuan_Left_2020-4-17_16-33-54_original.png -> /Users/txh/Desktop/kmeans_segment/36/period4_0046yangzhengxuan_Left_2020-4-17_16-33-54_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/36/period5_0046yangzhengxuan_Left_2021-01-9_15-25-07_original.png -> /Users/txh/Desktop/kmeans_segment/36/period5_0046yangzhengxuan_Left_2021-01-9_15-25-07_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/37/period1_0047zangyuzhao_Left_2020-09-26_10-11-15_original.png -> /Users/txh/Desktop/kmeans_segment/37/period1_0047zangyuzhao_Left_2020-09-26_10-11-15_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/37/period2_0047zangyuzhao_Left_2020-11-21_13-30-27_original.png -> /Users/txh/Desktop/kmeans_segment/37/period2_0047zangyuzhao_Left_2020-11-21_13-30-27_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/37/period3_0047zangyuzhao_Left_2021-01-31_15-39-55_original.png -> /Users/txh/Desktop/kmeans_segment/37/period3_0047zangyuzhao_Left_2021-01-31_15-39-55_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/37/period4_0047zangyuzhao_Left_2021-06-6_15-18-47_original.png -> /Users/txh/Desktop/kmeans_segment/37/period4_0047zangyuzhao_Left_2021-06-6_15-18-47_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/37/period5_0047zangyuzhao_Left_2021-10-7_14-12-25_original.png -> /Users/txh/Desktop/kmeans_segment/37/period5_0047zangyuzhao_Left_2021-10-7_14-12-25_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/38/period1_0049chenziyue_Left_2019-08-17_16-51-01_original.png -> /Users/txh/Desktop/kmeans_segment/38/period1_0049chenziyue_Left_2019-08-17_16-51-01_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/38/period2_0049chenziyue_Left_2019-10-5_15-37-12_original.png -> /Users/txh/Desktop/kmeans_segment/38/period2_0049chenziyue_Left_2019-10-5_15-37-12_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/38/period3_0049chenziyue_Left_2019-11-30_09-23-45_original.png -> /Users/txh/Desktop/kmeans_segment/38/period3_0049chenziyue_Left_2019-11-30_09-23-45_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/38/period4_0049chenziyue_Left_2020-05-2_10-18-42_original.png -> /Users/txh/Desktop/kmeans_segment/38/period4_0049chenziyue_Left_2020-05-2_10-18-42_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/38/period5_0049chenziyue_Left_2020-11-21_11-28-45_original.png -> /Users/txh/Desktop/kmeans_segment/38/period5_0049chenziyue_Left_2020-11-21_11-28-45_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/39/period1_0050chenzixuan_Left_2019-08-17_16-49-14_original.png -> /Users/txh/Desktop/kmeans_segment/39/period1_0050chenzixuan_Left_2019-08-17_16-49-14_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/39/period2_0050chenzixuan_Left_2019-10-5_15-34-42_original.png -> /Users/txh/Desktop/kmeans_segment/39/period2_0050chenzixuan_Left_2019-10-5_15-34-42_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/39/period3_0050chenzixuan_Left_2019-11-30_09-25-05_original.png -> /Users/txh/Desktop/kmeans_segment/39/period3_0050chenzixuan_Left_2019-11-30_09-25-05_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/39/period4_0050chenzixuan_Left_2020-3-21_09-25-36_original.png -> /Users/txh/Desktop/kmeans_segment/39/period4_0050chenzixuan_Left_2020-3-21_09-25-36_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/39/period5_0050chenzixuan_Left_2020-11-21_11-27-52_original.png -> /Users/txh/Desktop/kmeans_segment/39/period5_0050chenzixuan_Left_2020-11-21_11-27-52_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/4/period1_0004liuyetong_Left_2021-07-18_10-22-17_original.png -> /Users/txh/Desktop/kmeans_segment/4/period1_0004liuyetong_Left_2021-07-18_10-22-17_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/4/period2_0004liuyetong_Left_2021-10-10_11-05-13_original.png -> /Users/txh/Desktop/kmeans_segment/4/period2_0004liuyetong_Left_2021-10-10_11-05-13_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/4/period3_0004liuyetong_Left_2021-11-13_15-05-26_original.png -> /Users/txh/Desktop/kmeans_segment/4/period3_0004liuyetong_Left_2021-11-13_15-05-26_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/4/period4_0004liuyetong_Left_2021-12-25_13-47-40_original.png -> /Users/txh/Desktop/kmeans_segment/4/period4_0004liuyetong_Left_2021-12-25_13-47-40_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/4/period5_0004liuyetong_Left_2022-04-23_10-17-13_original.png -> /Users/txh/Desktop/kmeans_segment/4/period5_0004liuyetong_Left_2022-04-23_10-17-13_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/5/period1_0005yechenxin_Left_2021-04-11_13-12-13_original.png -> /Users/txh/Desktop/kmeans_segment/5/period1_0005yechenxin_Left_2021-04-11_13-12-13_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/5/period3_0005yechenxin_Left_2021-08-21_13-50-30_original.png -> /Users/txh/Desktop/kmeans_segment/5/period3_0005yechenxin_Left_2021-08-21_13-50-30_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/5/period4_0005yechenxin_Left_2022-01-2_16-49-29_original.png -> /Users/txh/Desktop/kmeans_segment/5/period4_0005yechenxin_Left_2022-01-2_16-49-29_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/5/period5_0005yechenxin_Left_2022-6-17_15-30-57_original.png -> /Users/txh/Desktop/kmeans_segment/5/period5_0005yechenxin_Left_2022-6-17_15-30-57_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/6/period1_0007wuhaoyang_Left_2019-6-28_14-24-21_original.png -> /Users/txh/Desktop/kmeans_segment/6/period1_0007wuhaoyang_Left_2019-6-28_14-24-21_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/6/period2_0007wuhaoyang_Left_2019-12-7_12-51-53_original.png -> /Users/txh/Desktop/kmeans_segment/6/period2_0007wuhaoyang_Left_2019-12-7_12-51-53_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/6/period3_0007wuhaoyang_Left_2019-12-21_13-30-24_original.png -> /Users/txh/Desktop/kmeans_segment/6/period3_0007wuhaoyang_Left_2019-12-21_13-30-24_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/6/period4_0007wuhaoyang_Left_2020-8-14_12-59-39_original.png -> /Users/txh/Desktop/kmeans_segment/6/period4_0007wuhaoyang_Left_2020-8-14_12-59-39_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/6/period5_0007wuhaoyang_Left_2020-11-15_16-35-44_original.png -> /Users/txh/Desktop/kmeans_segment/6/period5_0007wuhaoyang_Left_2020-11-15_16-35-44_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/7/period1_0008sundaiwen_Left_2019-08-24_09-09-33_original.png -> /Users/txh/Desktop/kmeans_segment/7/period1_0008sundaiwen_Left_2019-08-24_09-09-33_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/7/period2_0008sundaiwen_Left_2019-10-12_16-30-58_original.png -> /Users/txh/Desktop/kmeans_segment/7/period2_0008sundaiwen_Left_2019-10-12_16-30-58_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/7/period3_0008sundaiwen_Left_2019-11-30_10-23-54_original.png -> /Users/txh/Desktop/kmeans_segment/7/period3_0008sundaiwen_Left_2019-11-30_10-23-54_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/7/period4_0008sundaiwen_Left_2020-02-22_10-05-37_original.png -> /Users/txh/Desktop/kmeans_segment/7/period4_0008sundaiwen_Left_2020-02-22_10-05-37_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/7/period5_0008sundaiwen_Left_2020-08-29_10-36-30_original.png -> /Users/txh/Desktop/kmeans_segment/7/period5_0008sundaiwen_Left_2020-08-29_10-36-30_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/8/period1_0009caozheng_Left_2018-11-9_13-56-37_original.png -> /Users/txh/Desktop/kmeans_segment/8/period1_0009caozheng_Left_2018-11-9_13-56-37_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/8/period2_0009caozheng_Left_2019-01-4_14-11-45_original.png -> /Users/txh/Desktop/kmeans_segment/8/period2_0009caozheng_Left_2019-01-4_14-11-45_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/8/period3_0009caozheng_Left_2019-01-26_11-35-42_original.png -> /Users/txh/Desktop/kmeans_segment/8/period3_0009caozheng_Left_2019-01-26_11-35-42_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/8/period4_0009caozheng_Left_2019-05-4_11-31-14_original.png -> /Users/txh/Desktop/kmeans_segment/8/period4_0009caozheng_Left_2019-05-4_11-31-14_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/8/period5_0009caozheng_Left_2019-12-13_16-55-21_original.png -> /Users/txh/Desktop/kmeans_segment/8/period5_0009caozheng_Left_2019-12-13_16-55-21_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/9/period1_0010biantongyao_Left_2019-11-23_13-24-23_original.png -> /Users/txh/Desktop/kmeans_segment/9/period1_0010biantongyao_Left_2019-11-23_13-24-23_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/9/period2_0010biantongyao_Left_2019-12-21_14-32-05_original.png -> /Users/txh/Desktop/kmeans_segment/9/period2_0010biantongyao_Left_2019-12-21_14-32-05_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/9/period3_0010biantongyao_Left_2020-4-17_14-21-29_original.png -> /Users/txh/Desktop/kmeans_segment/9/period3_0010biantongyao_Left_2020-4-17_14-21-29_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/9/period4_0010biantongyao_Left_2020-08-1_13-33-11_original.png -> /Users/txh/Desktop/kmeans_segment/9/period4_0010biantongyao_Left_2020-08-1_13-33-11_original_kmeans_segment.png
# 处理完成: /Users/txh/Desktop/research/lwk/ok/6.0_original/9/period5_0010biantongyao_Left_2021-01-9_11-54-32_original.png -> /Users/txh/Desktop/kmeans_segment/9/period5_0010biantongyao_Left_2021-01-9_11-54-32_original_kmeans_segment.png
